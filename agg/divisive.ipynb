# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
x , _ = make_blobs(n_samples=200,centers= 1,cluster_std=2,random_state=42)

# %%
def divisive_clustering(data, max_clusters =4 ):
    cluster = [data]
    labels =np.zeros(len(data),dtype=int)
    while len(cluster) < max_clusters:
        #find the cluster with the largest number of points
        idx_to_split = np.argmax([len(c) for c in cluster])
        #this is the cluster we want to split
        cluster_to_split = cluster.pop[idx_to_split]
        #get a new label to assign to the newly foeward cluster 
        current_label = np.max(labels) + 1
        ##kmeans to split the cluster 
        kmeans = KMeans(n_clusters=2, random_state=42)
        split_labels = kmeans.fit_predict(cluster_to_split)
        ##divides the cluster into two based on kmeans data
        cluster1 = cluster_to_split[split_labels == 0]
        cluster2 = cluster_to_split[split_labels == 1]
        #add the new clusters back into the list
        clusters.append(cluster1)
        clusters.append(cluster2)
        ##update lables assignment
        label_indices = np.where([np.any(np.all(x == cluster_to_split, axis=1)) for x in data])[0]
        label_subset = split_lables
        labels[label_indices] = current_label
        labls[label_indices[label_subset == 0]] = current_label
        [label_indices[label_subset == 1]] = current_label + 1

    return lables

# %%
cluster_lables = divisive_clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(x)
cluster_labels = kmeans.labels_

plt.scatter(x[:, 0], x[:, 1], c=cluster_labels)
plt.grid(True)
plt.show()
